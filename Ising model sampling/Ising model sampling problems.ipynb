# %% [markdown]
# # Ising model sampling problems

# %% [markdown]
# ## Question 1: Ising model MCMC

# %% [markdown]
# ### Learning objectives
# In this question you will:
#
# - implement an MCMC algorithm
# - sample the Ising model at various temperatures

# %% [markdown]
# Markoc Chain Monte Carlo (MCMC) is a type of Monte Carlo technique (solving problems using radnom sampling) that seeks to sample a probability distribution by engineering a Markov chain (a probabilistic system where the probability distribution of the next state is completely determined by the current state) that will equilibrate to that distribution, and sampling that Markov chain for long times.

# %% [markdown]
# ### 1a.

# %% [markdown]
# A Markov chain is defined by its transition probabilities, i.e. $p(x_{n+1}|x_n)$. A stationary distribution is one that is left unchanged by evolution, i.e. $p(x_n=x)=\pi(x)\implies p(x_{n+1}=x)=\pi(x)$. Show that if a distribution $\pi$ satisfies detailed balance, $p(x|y)\pi(y)=p(y|x)\pi(x)$, then it is stationary.

# %% [markdown]
# Write your answer here

# %% [markdown]
# ### 1b.

# %% [markdown]
# To do MCMC, we need to construct transition probabilities $p(x|y)$ for which a given $\pi(x)$ is stationary (and assume that the Markov chain equilibrates to it, which you can take on faith for now). A common way to do this, known as the Metropolis-Hastings algorithm, is to use some reversible algorithm to suggest transitions (i.e. $T(x|y)=T(y|x)$), and for a suggested transition from $x$ to $y$, go to $y$ with probability $A(y,x)=\min\!\left(1,\frac{\pi(y)}{\pi(x)}\right)$ and remain at $x$ otherwise.
#
# Show that $\pi$ satisfies detailed balance, and is hence stationary, for this Markov chain.

# %% [markdown]
# Write your answer here

# %% [markdown]
# ### 1c.

# %% [markdown]
# Implement an MCMC algorithm using the Metropolis-Hastings algorithm to sample the 2d Ising model at a given temperature. Keep track of the energy and use the energy history to assess whether the system has equilibrated. Try it at a few different temperatures. How sharp is the transition between the ordered and disordered phase, and how does that change with the system size? Try to identify the critical temperature.
#
# Recall that the Ising model Hamiltonian is $$H=-J\sum_{\text{neighbours }i,j}\sigma_i\sigma_j.$$
#
# (Hint: a simple suggested transition would be to flip a randomly selected spin.)

# %%
#Write your answer here
