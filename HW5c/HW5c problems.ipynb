# %% [markdown]
# # HW5c problems

# %% [markdown]
# ## Question 1: Adsorption and hydrogen storage

# %% [markdown]
# ### Learning objectives
# In this question you will:
#
# - study adsorption and diffusive equilbrium
# - apply statistical mechanics to real-world problems
# - numerically solve constraints and optimise functions

# %% [markdown]
# ### 1a.

# %% [markdown]
# $\newcommand{\eps}{\epsilon}$Consider an adsorbing surface with $N$ localised sites that can each adsorb at most one particle. Suppose the energy of the adsorbed state of each site is $\epsilon_0$ lower (i.e. more favourable) than the free state. If the surface is immersed in a particle bath at a given temperature and chemical potential, what is  the probability distribtion of $n$, the number of occupied sites? What is the coverage $\theta=\frac{\langle n\rangle}{N}$?

# %% [markdown]
# Write your answer here

# %% [markdown]
# ### 1b.

# %% [markdown]
# <div style="width: 200px;margin: auto" align="center">
#     <br>
#     <img src="ideal_gas_adsorption.jpg">
#     An ideal gas chamber with an adsorbing surface.
# </div>
#
# Consider the setup in the image above, where we have an adsorbing surface in a container with a movable lid containing a large amount of ideal gas, inside an even larger environment at temerature $T$ and pressure $p$. Show that the coverage can be written $$\theta=\frac{p}{p_0(\eps_0,T)+p},$$ and find $p_0(\eps_0,T)$.

# %% [markdown]
# Write your answer here

# %% [markdown]
# ### 1c.

# %% [markdown]
# Hydrogen ($H_2$) is an efficient fuel because it is light, and thus has lots of extractable energy per unit mass. However, due to its low density it is difficult to store efficiently: as a gas we need it needs to be at a high pressure to have a high density, and as a liquid it needs to be at a very low temperature. In this problem we will explore storing it in an adsorbing surface.
#
# Suppose we are designing such a surface. Plot the coverage as a function of $\eps_0$ (in eV) at room temperature ($300~\rm K$) and at $100^\circ~\rm C$, at atmospheric pressure.
#
# (Hint: the module [`scipy.constants`](https://docs.scipy.org/doc/scipy/reference/constants.html) might be helpful.)

# %%
#Write your answer here

# %% [markdown]
# ### 1d.

# %% [markdown]
# Find the range of $\eps_0$ that allows at least half the surface to be occupied in standard conditions (room temperature, atmospheric pressure), and at least half of the molecules adsorbed at room temperature to be released at $100^\circ~\rm C$.
#
# (Hint: use the [`scipy.optimize` module](https://docs.scipy.org/doc/scipy/reference/optimize.html) to numerically solve equations where required. See the tutorial for more guidance: [GitHub](https://github.com/berkeley-physics/Python-Tutorials/blob/master/3%20-%20Specific%20topics/Solving%20equations.ipynb), [DataHub](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fberkeley-physics%2FPython-Tutorials&urlpath=tree%2FPython-Tutorials%2F3+-+Specific+topics%2FSolving+equations.ipynb&branch=master).)

# %%
#Write your answer here

# %% [markdown]
# ### 1e.

# %% [markdown]
# Find the $\eps_0$ that maximises the total amount of hydrogen that is absorbed at room temperature and released at $100^\circ~\rm C$.

# %%
#Write your answer here
